# %%
import pandas as pd
import numpy as np

# %%
np.random.seed(20)
df=pd.DataFrame(np.random.randn(10,4), index=pd.date_range('2022-03-22', periods= 10), columns= ['a','b','c','d'])

# %%
df
# Out:
#                    a         b         c         d
# 2022-03-22  0.883893  0.195865  0.357537 -2.343262
# 2022-03-23 -1.084833  0.559696  0.939469 -0.978481
# 2022-03-24  0.503097  0.406414  0.323461 -0.493411
# 2022-03-25 -0.792017 -0.842368 -1.279503  0.245715
# 2022-03-26 -0.044195  1.567633  1.051109  0.406368
# 2022-03-27 -0.168646 -3.189703  1.120132  1.332778
# 2022-03-28 -0.243339 -0.130031 -0.109017  1.556186
# 2022-03-29  0.128778 -2.066949 -0.885493 -1.104579
# 2022-03-30  0.932866  2.059838 -0.934938 -1.612990
# 2022-03-31  0.527070 -1.551101  0.329613 -1.136527

# %%
df['new'] = df['c']+df['d']

# %%
df
# Out:
#                    a         b         c         d       new
# 2022-03-22  0.883893  0.195865  0.357537 -2.343262 -1.985725
# 2022-03-23 -1.084833  0.559696  0.939469 -0.978481 -0.039012
# 2022-03-24  0.503097  0.406414  0.323461 -0.493411 -0.169950
# 2022-03-25 -0.792017 -0.842368 -1.279503  0.245715 -1.033787
# 2022-03-26 -0.044195  1.567633  1.051109  0.406368  1.457477
# 2022-03-27 -0.168646 -3.189703  1.120132  1.332778  2.452910
# 2022-03-28 -0.243339 -0.130031 -0.109017  1.556186  1.447169
# 2022-03-29  0.128778 -2.066949 -0.885493 -1.104579 -1.990073
# 2022-03-30  0.932866  2.059838 -0.934938 -1.612990 -2.547928
# 2022-03-31  0.527070 -1.551101  0.329613 -1.136527 -0.806913

# %%
df['new_col_square_d']= df['d'].apply(lambda x:x**2)

# %%
df
# Out:
#                    a         b         c         d       new  new_col_square_d
# 2022-03-22  0.883893  0.195865  0.357537 -2.343262 -1.985725          5.490876
# 2022-03-23 -1.084833  0.559696  0.939469 -0.978481 -0.039012          0.957425
# 2022-03-24  0.503097  0.406414  0.323461 -0.493411 -0.169950          0.243454
# 2022-03-25 -0.792017 -0.842368 -1.279503  0.245715 -1.033787          0.060376
# 2022-03-26 -0.044195  1.567633  1.051109  0.406368  1.457477          0.165135
# 2022-03-27 -0.168646 -3.189703  1.120132  1.332778  2.452910          1.776298
# 2022-03-28 -0.243339 -0.130031 -0.109017  1.556186  1.447169          2.421716
# 2022-03-29  0.128778 -2.066949 -0.885493 -1.104579 -1.990073          1.220096
# 2022-03-30  0.932866  2.059838 -0.934938 -1.612990 -2.547928          2.601737
# 2022-03-31  0.527070 -1.551101  0.329613 -1.136527 -0.806913          1.291693

# %%
df['new_col_log_d']= df['d'].apply(lambda x:np.log(x))

# %%
df
# Out:
#                    a         b         c         d       new  \
# 2022-03-22  0.883893  0.195865  0.357537 -2.343262 -1.985725
# 2022-03-23 -1.084833  0.559696  0.939469 -0.978481 -0.039012
# 2022-03-24  0.503097  0.406414  0.323461 -0.493411 -0.169950
# 2022-03-25 -0.792017 -0.842368 -1.279503  0.245715 -1.033787
# 2022-03-26 -0.044195  1.567633  1.051109  0.406368  1.457477
# 2022-03-27 -0.168646 -3.189703  1.120132  1.332778  2.452910
# 2022-03-28 -0.243339 -0.130031 -0.109017  1.556186  1.447169
# 2022-03-29  0.128778 -2.066949 -0.885493 -1.104579 -1.990073
# 2022-03-30  0.932866  2.059838 -0.934938 -1.612990 -2.547928
# 2022-03-31  0.527070 -1.551101  0.329613 -1.136527 -0.806913
#
#             new_col_square_d  new_col_log_d
# 2022-03-22          5.490876            NaN
# 2022-03-23          0.957425            NaN
# 2022-03-24          0.243454            NaN
# 2022-03-25          0.060376      -1.403582
# 2022-03-26          0.165135      -0.900495
# ...

# %%
def test(x):
    if x<0:
        return x
    else:
        return np.log(x)

# %%
df['new_col_log_d_log1']= df['d'].apply(test)

# %%
df
# Out:
#                    a         b         c         d       new  \
# 2022-03-22  0.883893  0.195865  0.357537 -2.343262 -1.985725
# 2022-03-23 -1.084833  0.559696  0.939469 -0.978481 -0.039012
# 2022-03-24  0.503097  0.406414  0.323461 -0.493411 -0.169950
# 2022-03-25 -0.792017 -0.842368 -1.279503  0.245715 -1.033787
# 2022-03-26 -0.044195  1.567633  1.051109  0.406368  1.457477
# 2022-03-27 -0.168646 -3.189703  1.120132  1.332778  2.452910
# 2022-03-28 -0.243339 -0.130031 -0.109017  1.556186  1.447169
# 2022-03-29  0.128778 -2.066949 -0.885493 -1.104579 -1.990073
# 2022-03-30  0.932866  2.059838 -0.934938 -1.612990 -2.547928
# 2022-03-31  0.527070 -1.551101  0.329613 -1.136527 -0.806913
#
#             new_col_square_d  new_col_log_d  new_col_log_d_log1
# 2022-03-22          5.490876            NaN           -2.343262
# 2022-03-23          0.957425            NaN           -0.978481
# 2022-03-24          0.243454            NaN           -0.493411
# ...

# %%
# If dataset in a is positive return 1 else 0

# %%
def test1(x):
    if x>0:
        return 1
    else:
        return 0

# %%
df['new_a']= df['a'].apply(test1)

# %%
df
# Out:
#                    a         b         c         d       new  \
# 2022-03-22  0.883893  0.195865  0.357537 -2.343262 -1.985725
# 2022-03-23 -1.084833  0.559696  0.939469 -0.978481 -0.039012
# 2022-03-24  0.503097  0.406414  0.323461 -0.493411 -0.169950
# 2022-03-25 -0.792017 -0.842368 -1.279503  0.245715 -1.033787
# 2022-03-26 -0.044195  1.567633  1.051109  0.406368  1.457477
# 2022-03-27 -0.168646 -3.189703  1.120132  1.332778  2.452910
# 2022-03-28 -0.243339 -0.130031 -0.109017  1.556186  1.447169
# 2022-03-29  0.128778 -2.066949 -0.885493 -1.104579 -1.990073
# 2022-03-30  0.932866  2.059838 -0.934938 -1.612990 -2.547928
# 2022-03-31  0.527070 -1.551101  0.329613 -1.136527 -0.806913
#
#             new_col_square_d  new_col_log_d  new_col_log_d_log1  new_a
# 2022-03-22          5.490876            NaN           -2.343262      1
# 2022-03-23          0.957425            NaN           -0.978481      0
# 2022-03-24          0.243454            NaN           -0.493411      1
# ...

# %%
df.sort_values(by = 'b')  ############################### sort values########################
# Out:
#                    a         b         c         d       new  \
# 2022-03-27 -0.168646 -3.189703  1.120132  1.332778  2.452910
# 2022-03-29  0.128778 -2.066949 -0.885493 -1.104579 -1.990073
# 2022-03-31  0.527070 -1.551101  0.329613 -1.136527 -0.806913
# 2022-03-25 -0.792017 -0.842368 -1.279503  0.245715 -1.033787
# 2022-03-28 -0.243339 -0.130031 -0.109017  1.556186  1.447169
# 2022-03-22  0.883893  0.195865  0.357537 -2.343262 -1.985725
# 2022-03-24  0.503097  0.406414  0.323461 -0.493411 -0.169950
# 2022-03-23 -1.084833  0.559696  0.939469 -0.978481 -0.039012
# 2022-03-26 -0.044195  1.567633  1.051109  0.406368  1.457477
# 2022-03-30  0.932866  2.059838 -0.934938 -1.612990 -2.547928
#
#             new_col_square_d  new_col_log_d  new_col_log_d_log1  new_a
# 2022-03-27          1.776298       0.287266            0.287266      0
# 2022-03-29          1.220096            NaN           -1.104579      1
# 2022-03-31          1.291693            NaN           -1.136527      1
# ...

# %%
df.index
# Out:
# DatetimeIndex(['2022-03-22', '2022-03-23', '2022-03-24', '2022-03-25',
#                '2022-03-26', '2022-03-27', '2022-03-28', '2022-03-29',
#                '2022-03-30', '2022-03-31'],
#               dtype='datetime64[ns]', freq='D')

# %%
#############3 How to treat index as a column##################################

# %%
df
# Out:
#                    a         b         c         d       new  \
# 2022-03-22  0.883893  0.195865  0.357537 -2.343262 -1.985725
# 2022-03-23 -1.084833  0.559696  0.939469 -0.978481 -0.039012
# 2022-03-24  0.503097  0.406414  0.323461 -0.493411 -0.169950
# 2022-03-25 -0.792017 -0.842368 -1.279503  0.245715 -1.033787
# 2022-03-26 -0.044195  1.567633  1.051109  0.406368  1.457477
# 2022-03-27 -0.168646 -3.189703  1.120132  1.332778  2.452910
# 2022-03-28 -0.243339 -0.130031 -0.109017  1.556186  1.447169
# 2022-03-29  0.128778 -2.066949 -0.885493 -1.104579 -1.990073
# 2022-03-30  0.932866  2.059838 -0.934938 -1.612990 -2.547928
# 2022-03-31  0.527070 -1.551101  0.329613 -1.136527 -0.806913
#
#             new_col_square_d  new_col_log_d  new_col_log_d_log1  new_a
# 2022-03-22          5.490876            NaN           -2.343262      1
# 2022-03-23          0.957425            NaN           -0.978481      0
# 2022-03-24          0.243454            NaN           -0.493411      1
# ...

# %%
df['df_date'] = df.index

# %%
df
# Out:
#                    a         b         c         d       new  \
# 2022-03-22  0.883893  0.195865  0.357537 -2.343262 -1.985725
# 2022-03-23 -1.084833  0.559696  0.939469 -0.978481 -0.039012
# 2022-03-24  0.503097  0.406414  0.323461 -0.493411 -0.169950
# 2022-03-25 -0.792017 -0.842368 -1.279503  0.245715 -1.033787
# 2022-03-26 -0.044195  1.567633  1.051109  0.406368  1.457477
# 2022-03-27 -0.168646 -3.189703  1.120132  1.332778  2.452910
# 2022-03-28 -0.243339 -0.130031 -0.109017  1.556186  1.447169
# 2022-03-29  0.128778 -2.066949 -0.885493 -1.104579 -1.990073
# 2022-03-30  0.932866  2.059838 -0.934938 -1.612990 -2.547928
# 2022-03-31  0.527070 -1.551101  0.329613 -1.136527 -0.806913
#
#             new_col_square_d  new_col_log_d  new_col_log_d_log1  new_a  \
# 2022-03-22          5.490876            NaN           -2.343262      1
# 2022-03-23          0.957425            NaN           -0.978481      0
# 2022-03-24          0.243454            NaN           -0.493411      1
# ...

# %%
df.dtypes
# Out:
# a                            float64
# b                            float64
# c                            float64
# d                            float64
# new                          float64
# new_col_square_d             float64
# new_col_log_d                float64
# new_col_log_d_log1           float64
# new_a                          int64
# df_date               datetime64[ns]
# dtype: object

# %%
######################## Date separation ######################
# month , date and year

# %%
df['day'] = df.index.day
df['month'] = df.index.month
df['year'] = df.index.year
df
# Out:
#                    a         b         c         d       new  \
# 2022-03-22  0.883893  0.195865  0.357537 -2.343262 -1.985725
# 2022-03-23 -1.084833  0.559696  0.939469 -0.978481 -0.039012
# 2022-03-24  0.503097  0.406414  0.323461 -0.493411 -0.169950
# 2022-03-25 -0.792017 -0.842368 -1.279503  0.245715 -1.033787
# 2022-03-26 -0.044195  1.567633  1.051109  0.406368  1.457477
# 2022-03-27 -0.168646 -3.189703  1.120132  1.332778  2.452910
# 2022-03-28 -0.243339 -0.130031 -0.109017  1.556186  1.447169
# 2022-03-29  0.128778 -2.066949 -0.885493 -1.104579 -1.990073
# 2022-03-30  0.932866  2.059838 -0.934938 -1.612990 -2.547928
# 2022-03-31  0.527070 -1.551101  0.329613 -1.136527 -0.806913
#
#             new_col_square_d  new_col_log_d  new_col_log_d_log1  new_a  \
# 2022-03-22          5.490876            NaN           -2.343262      1
# 2022-03-23          0.957425            NaN           -0.978481      0
# 2022-03-24          0.243454            NaN           -0.493411      1
# ...

# %%
############################## grouping operation############################

# %%
############### name of the day ##########################

# %%
df['day']= df.index.day_name()

# %%
df
# Out:
#                    a         b         c         d       new  \
# 2022-03-22  0.883893  0.195865  0.357537 -2.343262 -1.985725
# 2022-03-23 -1.084833  0.559696  0.939469 -0.978481 -0.039012
# 2022-03-24  0.503097  0.406414  0.323461 -0.493411 -0.169950
# 2022-03-25 -0.792017 -0.842368 -1.279503  0.245715 -1.033787
# 2022-03-26 -0.044195  1.567633  1.051109  0.406368  1.457477
# 2022-03-27 -0.168646 -3.189703  1.120132  1.332778  2.452910
# 2022-03-28 -0.243339 -0.130031 -0.109017  1.556186  1.447169
# 2022-03-29  0.128778 -2.066949 -0.885493 -1.104579 -1.990073
# 2022-03-30  0.932866  2.059838 -0.934938 -1.612990 -2.547928
# 2022-03-31  0.527070 -1.551101  0.329613 -1.136527 -0.806913
#
#             new_col_square_d  new_col_log_d  new_col_log_d_log1  new_a  \
# 2022-03-22          5.490876            NaN           -2.343262      1
# 2022-03-23          0.957425            NaN           -0.978481      0
# 2022-03-24          0.243454            NaN           -0.493411      1
# ...

# %%
##################### groupby operation on day and what is the cound of the data

# %%
df.groupby(by= 'day').count()
# Out:
#            a  b  c  d  new  new_col_square_d  new_col_log_d  \
# day
# Friday     1  1  1  1    1                 1              1
# Monday     1  1  1  1    1                 1              1
# Saturday   1  1  1  1    1                 1              1
# Sunday     1  1  1  1    1                 1              1
# Thursday   2  2  2  2    2                 2              0
# Tuesday    2  2  2  2    2                 2              0
# Wednesday  2  2  2  2    2                 2              0
#
#            new_col_log_d_log1  new_a  df_date  month  year
# day
# Friday                      1      1        1      1     1
# Monday                      1      1        1      1     1
# Saturday                    1      1        1      1     1
# Sunday                      1      1        1      1     1
# Thursday                    2      2        2      2     2
# Tuesday                     2      2        2      2     2
# ...

# %% [markdown]
# # VISUALIZATION #############################

# %%
"""
VISUALIZATION AND DASHBOARDING ARE TWO DIFFERENT THINGS
VISUALIZATION IS THE INTERMEDIATORY THING 
RANDOM EXPERIMENT
PATTERN OF THE DATA 
ITS AN EXPERIMENTAL THING




DASHBOARDING IS MORE LIKE A REPORT 
FINAL REPORT
END OF THE PROJECT
"""

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
np.random.seed(20)
df1=pd.DataFrame(np.random.rand(1000,1), index=pd.date_range('2022-03-12', periods= 1000), columns= ['data'])

# %%
df1
# Out:
#                 data
# 2022-03-12  0.588131
# 2022-03-13  0.897714
# 2022-03-14  0.891531
# 2022-03-15  0.815837
# 2022-03-16  0.035890
# ...              ...
# 2024-12-01  0.992189
# 2024-12-02  0.756037
# 2024-12-03  0.299186
# 2024-12-04  0.261712
# 2024-12-05  0.968979
#
# [1000 rows x 1 columns]

# %%
df1.plot()
# Out:
# <AxesSubplot:>

# %%
df1.data.cumsum()
# Out:
# 2022-03-12      0.588131
# 2022-03-13      1.485845
# 2022-03-14      2.377375
# 2022-03-15      3.193213
# 2022-03-16      3.229102
#                  ...
# 2024-12-01    495.812936
# 2024-12-02    496.568973
# 2024-12-03    496.868159
# 2024-12-04    497.129872
# 2024-12-05    498.098851
# Freq: D, Name: data, Length: 1000, dtype: float64

# %%
df1.data.cumsum().plot()
# Out:
# <AxesSubplot:>

# %%
df1['data1'] = df1.data.cumsum()

# %%
df1['data2'] = df1['data'].apply(lambda x: x**x)

# %%
df1
# Out:
#                 data       data1     data2
# 2022-03-12  0.588131    0.588131  0.731847
# 2022-03-13  0.897714    1.485845  0.907677
# 2022-03-14  0.891531    2.377375  0.902703
# 2022-03-15  0.815837    3.193213  0.846999
# 2022-03-16  0.035890    3.229102  0.887439
# ...              ...         ...       ...
# 2024-12-01  0.992189  495.812936  0.992249
# 2024-12-02  0.756037  496.568973  0.809420
# 2024-12-03  0.299186  496.868159  0.696962
# 2024-12-04  0.261712  497.129872  0.704105
# 2024-12-05  0.968979  498.098851  0.969927
#
# [1000 rows x 3 columns]

# %%
df1.plot()
# Out:
# <AxesSubplot:>

# %%
df1.plot(figsize=(20,20))
# Out:
# <AxesSubplot:>

# %%
sns.load_dataset('iris')
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df2 = sns.load_dataset('iris')

# %%
df2
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df2.plot()
# Out:
# <AxesSubplot:>

# %%
df2.plot(figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
df2.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df2.plot(figsize=(10,10), title= "iris data")
# Out:
# <AxesSubplot:title={'center':'iris data'}>

# %%
gf =df2.plot(figsize=(10,10), title= "iris data")
gf.set_xlabel("This is my x axis")
gf.set_ylabel("This is my y axis")
# Out:
# Text(0, 0.5, 'This is my y axis')

# %%
df2
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df2.iloc[0][0:4]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: object

# %%
df2.iloc[0][0:4].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df2.iloc[0][0:4].plot()
# Out:
# <AxesSubplot:>

# %%
sns.load_dataset('titanic')
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df3 = sns.load_dataset('titanic')

# %%
df3['pclass'].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
pd.DataFrame(np.random.rand(10,4), columns= ['a','b','c','d'])
# Out:
#           a         b         c         d
# 0  0.534850  0.141536  0.997549  0.663146
# 1  0.310007  0.127744  0.547494  0.029529
# 2  0.344711  0.929877  0.579118  0.643341
# 3  0.557322  0.307009  0.887460  0.760641
# 4  0.249756  0.648684  0.123295  0.508399
# 5  0.174770  0.759351  0.493705  0.254648
# 6  0.393292  0.008692  0.296240  0.232336
# 7  0.841515  0.442961  0.656447  0.080341
# 8  0.719348  0.575515  0.577130  0.251678
# 9  0.166954  0.675000  0.177515  0.724717

# %%
df4 = pd.DataFrame(np.random.rand(10,4), columns= ['a','b','c','d'])

# %%
df4.plot.bar(figsize= (10,10))
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#                    a         b         c         d       new  \
# 2022-03-22  0.883893  0.195865  0.357537 -2.343262 -1.985725
# 2022-03-23 -1.084833  0.559696  0.939469 -0.978481 -0.039012
# 2022-03-24  0.503097  0.406414  0.323461 -0.493411 -0.169950
# 2022-03-25 -0.792017 -0.842368 -1.279503  0.245715 -1.033787
# 2022-03-26 -0.044195  1.567633  1.051109  0.406368  1.457477
# 2022-03-27 -0.168646 -3.189703  1.120132  1.332778  2.452910
# 2022-03-28 -0.243339 -0.130031 -0.109017  1.556186  1.447169
# 2022-03-29  0.128778 -2.066949 -0.885493 -1.104579 -1.990073
# 2022-03-30  0.932866  2.059838 -0.934938 -1.612990 -2.547928
# 2022-03-31  0.527070 -1.551101  0.329613 -1.136527 -0.806913
#
#             new_col_square_d  new_col_log_d  new_col_log_d_log1  new_a  \
# 2022-03-22          5.490876            NaN           -2.343262      1
# 2022-03-23          0.957425            NaN           -0.978481      0
# 2022-03-24          0.243454            NaN           -0.493411      1
# ...

# %%
df1
# Out:
#                 data       data1     data2
# 2022-03-12  0.588131    0.588131  0.731847
# 2022-03-13  0.897714    1.485845  0.907677
# 2022-03-14  0.891531    2.377375  0.902703
# 2022-03-15  0.815837    3.193213  0.846999
# 2022-03-16  0.035890    3.229102  0.887439
# ...              ...         ...       ...
# 2024-12-01  0.992189  495.812936  0.992249
# 2024-12-02  0.756037  496.568973  0.809420
# 2024-12-03  0.299186  496.868159  0.696962
# 2024-12-04  0.261712  497.129872  0.704105
# 2024-12-05  0.968979  498.098851  0.969927
#
# [1000 rows x 3 columns]

# %%
df2
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df3
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df4
# Out:
#           a         b         c         d
# 0  0.778792  0.756519  0.570900  0.284910
# 1  0.109605  0.602166  0.667412  0.132562
# 2  0.033660  0.393149  0.064322  0.035292
# 3  0.229727  0.398055  0.203181  0.531033
# 4  0.346681  0.055199  0.475264  0.364889
# 5  0.620332  0.537519  0.757538  0.430134
# 6  0.552645  0.003306  0.484264  0.109020
# 7  0.752745  0.583526  0.436770  0.261587
# 8  0.550545  0.876907  0.100145  0.177096
# 9  0.404380  0.021534  0.004542  0.360291

# %%
df4.plot.barh()
# Out:
# <AxesSubplot:>

# %%
df3
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df2
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df2.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df2['sepal_width']
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64

# %%
df2.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df2['sepal_width'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
############## from historgram we get the frequency of the data between range################

# %%
df2.plot(kind= 'hist', stacked= True , bins=100 , figsize= (10,10), title = 'iris historgram' )
# Out:
# <AxesSubplot:title={'center':'iris historgram'}, ylabel='Frequency'>

# %%
df2.plot(kind= 'hist', stacked= True , bins=100 , figsize= (10,10), title = 'iris historgram' , orientation = 'horizontal')
# Out:
# <AxesSubplot:title={'center':'iris historgram'}, xlabel='Frequency'>

# %%
df2.hist(figsize= (10,10), color = '#66ff99' , alpha = 0.1)
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
df2.hist(figsize= (10,10), color = '#66ff99' , alpha = 0.5)
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
df2.hist(figsize= (10,10), color = '#66ff99' , alpha = 0.9)
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
df2
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# in case we have to understand relationship between one attribute to another attribute

# %%
df2.plot.scatter(x = 'sepal_length', y= 'petal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>

# %%
df2.plot.scatter(x = 'sepal_length', y= 'petal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>

# %%
df2.plot.scatter(x = 'sepal_length', y= 'petal_width',c = 'petal_length')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>

# %%
df2.plot.scatter(x ='sepal_length' , y = 'sepal_width' , label= 'adi' )
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
df2.plot.scatter(x ='sepal_length' , y = 'sepal_width' , label= 'adi' , s = 50)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
df2.plot.scatter(x ='sepal_length' , y = 'sepal_width' , label= 'adi' , s = 50 , c = 'petal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %% [markdown]
# # df2.plot.hexbin(x ='sepal_length' , y = 'sepal_width' , label= 'adi',gridsize= 10)

# %%
df1
# Out:
#                 data       data1     data2
# 2022-03-12  0.588131    0.588131  0.731847
# 2022-03-13  0.897714    1.485845  0.907677
# 2022-03-14  0.891531    2.377375  0.902703
# 2022-03-15  0.815837    3.193213  0.846999
# 2022-03-16  0.035890    3.229102  0.887439
# ...              ...         ...       ...
# 2024-12-01  0.992189  495.812936  0.992249
# 2024-12-02  0.756037  496.568973  0.809420
# 2024-12-03  0.299186  496.868159  0.696962
# 2024-12-04  0.261712  497.129872  0.704105
# 2024-12-05  0.968979  498.098851  0.969927
#
# [1000 rows x 3 columns]

# %%
d = df1.iloc[0]

# %%
d
# Out:
# data     0.588131
# data1    0.588131
# data2    0.731847
# Name: 2022-03-12 00:00:00, dtype: float64

# %%
d.plot.pie(figsize= (8,8))
# Out:
# <AxesSubplot:ylabel='2022-03-12 00:00:00'>

# %%
df2
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df2.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %%
iris = df2.head(3).T

# %%
iris
# Out:
#                    0       1       2
# sepal_length     5.1     4.9     4.7
# sepal_width      3.5     3.0     3.2
# petal_length     1.4     1.4     1.3
# petal_width      0.2     0.2     0.2
# species       setosa  setosa  setosa

# %%
iris.iloc[0:4]
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
iris.iloc[0:4].plot.pie(figsize=(20,20),subplots = True)
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>], dtype=object)

# %%
iris.iloc[0:4].plot.pie(figsize=(20,20),subplots = True , fontsize = 20 , autopct= '%.2f')
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>], dtype=object)

# %%
df2
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
pd.plotting.scatter_matrix(df2 , figsize = (10,10))
# Out:
# array([[<AxesSubplot:xlabel='sepal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_width'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='petal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>,
# ...

# %%
pd.plotting.scatter_matrix(df2 , figsize = (10,10), diagonal= 'kde')
# Out:
# array([[<AxesSubplot:xlabel='sepal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_width'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='petal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>,
# ...

# %%
df1
# Out:
#                 data       data1     data2
# 2022-03-12  0.588131    0.588131  0.731847
# 2022-03-13  0.897714    1.485845  0.907677
# 2022-03-14  0.891531    2.377375  0.902703
# 2022-03-15  0.815837    3.193213  0.846999
# 2022-03-16  0.035890    3.229102  0.887439
# ...              ...         ...       ...
# 2024-12-01  0.992189  495.812936  0.992249
# 2024-12-02  0.756037  496.568973  0.809420
# 2024-12-03  0.299186  496.868159  0.696962
# 2024-12-04  0.261712  497.129872  0.704105
# 2024-12-05  0.968979  498.098851  0.969927
#
# [1000 rows x 3 columns]

# %%
df1['data'].plot(style= '*')
# Out:
# <AxesSubplot:>

# %%
df1['data'].plot(style= 'r*', legend= True , label = 'adi', figsize= (10,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # PLOT LIB #################

# %%
# !pip install plotly
# !pip install cufflinks

# %%
from plotly.offline import iplot
import plotly as py
import plotly.tools as tls
import cufflinks as cf

# %%
df2
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
py.offline.init_notebook_mode(connected= True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
# ...

# %%
df2.iplot()
# Out:
# <div>                            <div id="62e6bf56-9dd4-4177-8ad3-7eda3cda68a0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
