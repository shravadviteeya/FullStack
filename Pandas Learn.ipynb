# %%
import pandas as pd

# %%
# file read and write operation

# %%
pd.read_excel("G:\My Drive\Data\data power supply.xlsx")
# Out:
#     Date Time  Temmperature  humidity  Wind speed  General diffuse flows  \
# 0  2022-01-01            67         4         177               0.210125
# 1  2022-01-02            26         4         122               0.128509
# 2  2022-01-03            58         7         172               0.537862
# 3  2022-01-04            68         6          97               0.818062
# 4  2022-01-05            20         4         184               0.514938
# 5  2022-01-06            20         9         124               0.498937
# 6  2022-01-07            45         7         284               0.439151
# 7  2022-01-08            55         6         264               0.041091
# 8  2022-01-09            47         1         209               0.180481
# 9  2022-01-10            57         7         259               0.156179
# 10 2022-01-11            33         7          81               0.750898
#
#     power 1  power 2  power 3
# 0        40       31       38
# ...

# %%
#ls
#command is used to show the current working directory

# %%
# r is for unicode issue. in order to read the excel character

pd.read_excel(r"G:\My Drive\Data\data power supply.xlsx")
# Out:
#     Date Time  Temmperature  humidity  Wind speed  General diffuse flows  \
# 0  2022-01-01            67         4         177               0.210125
# 1  2022-01-02            26         4         122               0.128509
# 2  2022-01-03            58         7         172               0.537862
# 3  2022-01-04            68         6          97               0.818062
# 4  2022-01-05            20         4         184               0.514938
# 5  2022-01-06            20         9         124               0.498937
# 6  2022-01-07            45         7         284               0.439151
# 7  2022-01-08            55         6         264               0.041091
# 8  2022-01-09            47         1         209               0.180481
# 9  2022-01-10            57         7         259               0.156179
# 10 2022-01-11            33         7          81               0.750898
#
#     power 1  power 2  power 3
# 0        40       31       38
# ...

# %%
# it gives rows and columns automatically 
# first row is considered as a column
# pandas cant be used for unstructured data
# pandas is for structured data
# data type of entire table is dataframe (tabular structure)
#

# %%
df = pd.read_excel(r"G:\My Drive\Data\data power supply.xlsx")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# in case you dont want first row as a column
# header = 'infer' by default
# header = 'infer = None' then it gives a default header or column
# names = is used to change the name of the column name in the list

# %%
df1 = pd.read_csv("G:\\My Drive\\Data\\taxonomy.csv")

# %%
df1 # header = 'infer' by default
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df1 = pd.read_csv("G:\\My Drive\\Data\\taxonomy.csv", header= None)

# %%
df1 # header = 'infer = None' then it gives a default header or column
# Out:
#                0                             1          2  \
# 0    taxonomy_id                          name  parent_id
# 1            101                     Emergency        NaN
# 2         101-01             Disaster Response        101
# 3         101-02                Emergency Cash        101
# 4      101-02-01             Help Pay for Food     101-02
# ..           ...                           ...        ...
# 286    111-01-07              Workplace Rights     111-01
# 287       111-02                     Mediation        111
# 288       111-03                        Notary        111
# 289       111-04                Representation        111
# 290       111-05  Translation & Interpretation        111
#
#                         3
# 0             parent_name
# 1                     NaN
# 2               Emergency
# 3               Emergency
# 4          Emergency Cash
# ..                    ...
# 286  Advocacy & Legal Aid
# 287                 Legal
# ...

# %%
df1 = pd.read_csv("G:\\My Drive\\Data\\taxonomy.csv", names= ['a','b','c','d'])

# %% [markdown]
# # names = is used to change the name of the column name in the list

# %%
df1
# Out:
#                a                             b          c  \
# 0    taxonomy_id                          name  parent_id
# 1            101                     Emergency        NaN
# 2         101-01             Disaster Response        101
# 3         101-02                Emergency Cash        101
# 4      101-02-01             Help Pay for Food     101-02
# ..           ...                           ...        ...
# 286    111-01-07              Workplace Rights     111-01
# 287       111-02                     Mediation        111
# 288       111-03                        Notary        111
# 289       111-04                Representation        111
# 290       111-05  Translation & Interpretation        111
#
#                         d
# 0             parent_name
# 1                     NaN
# 2               Emergency
# 3               Emergency
# 4          Emergency Cash
# ..                    ...
# 286  Advocacy & Legal Aid
# 287                 Legal
# ...

# %%
df1 = pd.read_csv("G:\\My Drive\\Data\\taxonomy.csv", names= ['a','b','c'])

# %%
df1
# Out:
#                                         a          b                     c
# taxonomy_id                          name  parent_id           parent_name
# 101                             Emergency        NaN                   NaN
# 101-01                  Disaster Response        101             Emergency
# 101-02                     Emergency Cash        101             Emergency
# 101-02-01               Help Pay for Food     101-02        Emergency Cash
# ...                                   ...        ...                   ...
# 111-01-07                Workplace Rights     111-01  Advocacy & Legal Aid
# 111-02                          Mediation        111                 Legal
# 111-03                             Notary        111                 Legal
# 111-04                     Representation        111                 Legal
# 111-05       Translation & Interpretation        111                 Legal
#
# [291 rows x 3 columns]

# %%
pd.read_csv("G:\\My Drive\\Data\\holiday_schedules.csv")
# Out:
#    id  location_id  service_id        start_date            end_date  closed  \
# 0   1         22.0         NaN  January 01, 0001    January 01, 0001    True
# 1   2         22.0         NaN        12/24/2015            12/24/15   False
# 2   3         22.0         NaN     June 01, 0001  September 01, 0001    True
# 3   4          NaN        22.0  January 01, 0001    January 01, 0001    True
#
#   opens_at closes_at
# 0      NaN       NaN
# 1    10:00     16:00
# 2      NaN       NaN
# 3      NaN       NaN

# %%
# separated the ',' values with @

# %%
pd.read_csv("G:\\My Drive\\Data\\holiday_schedules.csv")
# Out:
#   id@location_id@service_id@start_date@end_date@closed@opens_at@closes_at
# 0  1@22@@"January 01@ 0001"@"January 01@ 0001"@tr...
# 1    2@22@@"12/24/2015"@"12/24/15"@false@10:00@16:00
# 2  3@22@@"June 01@ 0001"@"September 01@ 0001"@true@@
# 3  4@@22@"January 01@ 0001"@"January 01@ 0001"@tr...

# %%
pd.read_csv("G:\\My Drive\\Data\\holiday_schedules.csv", sep= '@')
# Out:
#    id  location_id  service_id        start_date            end_date  closed  \
# 0   1         22.0         NaN  January 01@ 0001    January 01@ 0001    True
# 1   2         22.0         NaN        12/24/2015            12/24/15   False
# 2   3         22.0         NaN     June 01@ 0001  September 01@ 0001    True
# 3   4          NaN        22.0  January 01@ 0001    January 01@ 0001    True
#
#   opens_at closes_at
# 0      NaN       NaN
# 1    10:00     16:00
# 2      NaN       NaN
# 3      NaN       NaN

# %%
pd.read_csv("G:\\My Drive\\Data\\holiday_schedules.csv", sep= '@')
# Out:
#   id|location_id|service_id|start_date|end_date|closed|opens_at|closes_at
# 0  1|22||"January 01| 0001"|"January 01| 0001"|tr...
# 1    2|22||"12/24/2015"|"12/24/15"|false|10:00|16:00
# 2  3|22||"June 01| 0001"|"September 01| 0001"|true||
# 3  4||22|"January 01| 0001"|"January 01| 0001"|tr...

# %%
pd.read_csv("G:\\My Drive\\Data\\holiday_schedules.csv", sep= '|')
# Out:
#    id  location_id  service_id        start_date            end_date  closed  \
# 0   1         22.0         NaN  January 01| 0001    January 01| 0001    True
# 1   2         22.0         NaN        12/24/2015            12/24/15   False
# 2   3         22.0         NaN     June 01| 0001  September 01| 0001    True
# 3   4          NaN        22.0  January 01| 0001    January 01| 0001    True
#
#   opens_at closes_at
# 0      NaN       NaN
# 1    10:00     16:00
# 2      NaN       NaN
# 3      NaN       NaN

# %%
# we can only use on separator at a time

# %%
pd.read_csv("G:\\My Drive\\Data\\holiday_schedules.csv")
# Out:
#   id@location_id@service_id@start_date@end_date@closed@opens_at@closes_at
# 0  1@22@@"January 01@ 0001"@"January 01@ 0001"@tr...
# 1    2@22@@"12/24/2015"@"12/24/15"@false@10:00@16:00
# 2  3@22@@"June 01@ 0001"@"September 01@ 0001"@true@@
# 3  4@@22@"January 01@ 0001"@"January 01@ 0001"@tr...

# %%
pd.read_csv("G:\\My Drive\\Data\\holiday_schedules.csv", sep= "|")
# Out:
#   id@location_id@service_id@start_date@end_date@closed@opens_at@closes_at
# 0  1@22@@"January 01@ 0001"@"January 01@ 0001"@tr...
# 1    2@22@@"12/24/2015"@"12/24/15"@false@10:00@16:00
# 2  3@22@@"June 01@ 0001"@"September 01@ 0001"@true@@
# 3  4@@22@"January 01@ 0001"@"January 01@ 0001"@tr...

# %%
pd.read_csv("G:\\My Drive\\Data\\holiday_schedules.csv")
# Out:
#   id|location_id|service_id|start_date|end_date|closed|opens_at|closes_at
# 0  1|22||"January 01| 0001"|"January 01| 0001"|tr...
# 1    2|22||"12/24/2015"|"12/24/15"|false|10:00|16:00
# 2  3|22||"June 01| 0001"|"September 01| 0001"|true||
# 3  4||22|"January 01| 0001"|"January 01| 0001"|tr...

# %%
pd.read_csv("G:\\My Drive\\Data\\holiday_schedules.csv", sep= "|")
# Out:
#    id  location_id  service_id        start_date            end_date  closed  \
# 0   1         22.0         NaN  January 01| 0001    January 01| 0001    True
# 1   2         22.0         NaN        12/24/2015            12/24/15   False
# 2   3         22.0         NaN     June 01| 0001  September 01| 0001    True
# 3   4          NaN        22.0  January 01| 0001    January 01| 0001    True
#
#   opens_at closes_at
# 0      NaN       NaN
# 1    10:00     16:00
# 2      NaN       NaN
# 3      NaN       NaN

# %%
pd.read_csv("G:\\My Drive\\Data\\holiday_schedules.csv", sep= "|", skiprows= [1,3])
# Out:
#    id  location_id  service_id        start_date          end_date  closed  \
# 0   2         22.0         NaN        12/24/2015          12/24/15   False
# 1   4          NaN        22.0  January 01| 0001  January 01| 0001    True
#
#   opens_at closes_at
# 0    10:00     16:00
# 1      NaN       NaN

# %%
pd.read_csv("G:\\My Drive\\Data\\services.csv")
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %%
df1 = pd.read_csv("G:\\My Drive\\Data\\services.csv")

# %%
df1
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1.dtypes # it returns the data types of each and every column
# Out:
# id                           int64
# location_id                  int64
# program_id                 float64
# accepted_payments           object
# alternate_name              object
# application_process         object
# audience                    object
# description                 object
# eligibility                 object
# email                       object
# fees                        object
# funding_sources             object
# interpretation_services     object
# keywords                    object
# languages                   object
# name                        object
# required_documents          object
# service_areas               object
# status                      object
# wait_time                   object
# website                     object
# taxonomy_ids                object
# dtype: object

# %%
df1.head()  # first five records or rows of a dataframe
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
# 3   4            4         NaN               NaN            NaN
# 4   5            5         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
# 3                              Apply by phone.
# 4                       Phone for information.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
# 3  Parents, children, families with problems of c...
# ...

# %%
df1.head(2)
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
#
#                   application_process  \
# 0          Walk in or apply by phone.
# 1  Apply by phone for an appointment.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
#
#                                          description  \
# 0  A walk-in center for older adults that provide...
# 1  Provides training and job placement to eligibl...
#
#                                          eligibility email  ...  \
# 0  Age 55 or over for most programs, age 60 or ov...   NaN  ...
# 1  Age 55 or over, county resident and willing an...   NaN  ...
#
#   interpretation_services                                           keywords  \
# ...

# %%
df1.tail()
# Out:
#     id  location_id  program_id         accepted_payments  \
# 18  19           19         NaN                       NaN
# 19  20           20         NaN                       NaN
# 20  21           21         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                             application_process  \
# 18                    NaN  Call for screening appointment (650-347-3648).
# 19                    NaN                                        Walk in.
# 20                    NaN                 By phone during business hours.
# 21  Fotos para pasaportes               Walk in or apply by phone or mail
# 22                    NaN               Walk in or apply by phone or mail
#
#                                              audience  \
# 18                                                NaN
# 19                                                NaN
# ...

# %%
df1.tail(2
        )
# Out:
#     id  location_id  program_id         accepted_payments  \
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                application_process  \
# 21  Fotos para pasaportes  Walk in or apply by phone or mail
# 22                    NaN  Walk in or apply by phone or mail
#
#                                              audience  \
# 21  Profit and nonprofit businesses, the public, m...
# 22  Second service and nonprofit businesses, the p...
#
#                                           description eligibility  \
# 21  [NOTE THIS IS NOT A REAL SERVICE--THIS IS FOR ...        None
# 22  [NOTE THIS IS NOT A REAL ORGANIZATION--THIS IS...        None
#
#                     email  ...  \
# 21  passports@example.org  ...
# 22                    NaN  ...
#
#                               interpretation_services  \
# 21  We offer 3-way interpretation services over th...
# ...

# %%
# in jupyter notebook we dont see all the reocrds but it reads all the records

# %%
df.columns
# Out:
# Index(['Date Time', 'Temmperature', 'humidity', 'Wind speed',
#        'General diffuse flows', 'power 1', 'power 2', 'power 3'],
#       dtype='object')

# %%
df1.columns
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='object')

# %%
# data from some of the columns

# %%
df1['service_areas']
# Out:
# 0                                     Colma
# 1                          San Mateo County
# 2                          San Mateo County
# 3                          San Mateo County
# 4                          San Mateo County
# 5                          San Mateo County
# 6       Belmont, Burlingame, East Palo Alto
# 7                   Belmont, East Palo Alto
# 8                          San Mateo County
# 9                          San Mateo County
# 10                         San Mateo County
# 11                                Daly City
# 12                         San Mateo County
# 13      Belmont, Burlingame, East Palo Alto
# 14         Alameda County, San Mateo County
# 15                                      NaN
# 16    Colma, Daly City, South San Francisco
# 17                           East Palo Alto
# 18                      Belmont, Burlingame
# 19                                      NaN
# 20                         San Mateo County
# ...

# %%
df1['status']
# Out:
# 0       active
# 1       active
# 2       active
# 3       active
# 4       active
# 5       active
# 6       active
# 7       active
# 8       active
# 9       active
# 10      active
# 11      active
# 12      active
# 13      active
# 14      active
# 15      active
# 16      active
# 17      active
# 18      active
# 19     defunct
# 20    inactive
# 21      active
# 22      active
# Name: status, dtype: object

# %%
# in case multiple columns

# %%
a = df1['status']

# %%
a
# Out:
# 0       active
# 1       active
# 2       active
# 3       active
# 4       active
# 5       active
# 6       active
# 7       active
# 8       active
# 9       active
# 10      active
# 11      active
# 12      active
# 13      active
# 14      active
# 15      active
# 16      active
# 17      active
# 18      active
# 19     defunct
# 20    inactive
# 21      active
# 22      active
# Name: status, dtype: object

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
type(df1['service_areas'])
# Out:
# pandas.core.series.Series

# %%
# in data frame we have series and dataframe
# data frame is same as all the operations in SQL
# in case you are going to pull out one single row and single column then it is call as series
# data frame is a combination of list

# %%
df1['languages', 'name']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('languages', 'name')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-55-ed452e6fb418> in <module>
# ...

# %%
# in case you have multiple columns you have to enclosed into 2 brackets 
# pass list as data frame

# %%
df1[['languages', 'name']]
# Out:
#    languages                                  name
# 0        NaN       Fair Oaks Adult Activity Center
# 1        NaN      Second Career Employment Program
# 2        NaN                Senior Peer Counseling
# 3        NaN              Family Visitation Center
# 4        NaN     Economic Self-Sufficiency Program
# 5        NaN  Little House Recreational Activities
# 6        NaN      Rosener House Adult Day Services
# 7        NaN        Meals on Wheels - South County
# 8        NaN                      Fair Oaks Branch
# 9        NaN                          Main Library
# 10       NaN                       Schaberg Branch
# 11       NaN                          Project Read
# 12       NaN                 Redwood Shores Branch
# 13       NaN                    Redwood City Corps
# 14       NaN           Adult Rehabilitation Center
# 15       NaN                       Sunnyvale Corps
# 16       NaN     South San Francisco Citadel Corps
# ...

# %%
b= df1[['languages', 'name']]
b
# Out:
#    languages                                  name
# 0        NaN       Fair Oaks Adult Activity Center
# 1        NaN      Second Career Employment Program
# 2        NaN                Senior Peer Counseling
# 3        NaN              Family Visitation Center
# 4        NaN     Economic Self-Sufficiency Program
# 5        NaN  Little House Recreational Activities
# 6        NaN      Rosener House Adult Day Services
# 7        NaN        Meals on Wheels - South County
# 8        NaN                      Fair Oaks Branch
# 9        NaN                          Main Library
# 10       NaN                       Schaberg Branch
# 11       NaN                          Project Read
# 12       NaN                 Redwood Shores Branch
# 13       NaN                    Redwood City Corps
# 14       NaN           Adult Rehabilitation Center
# 15       NaN                       Sunnyvale Corps
# 16       NaN     South San Francisco Citadel Corps
# ...

# %%
type(df1[['languages', 'name']])
# Out:
# pandas.core.frame.DataFrame

# %%
type(df1[['name']])
# Out:
# pandas.core.frame.DataFrame

# %%
# in case of a single column name in double brackets it is going ot pass as dataframe

# %%
# EXCEL FILE READING

# %%
pd.read_excel("LUSID Excel - Manage Orders.xlsx")
# Out:
#     Unnamed: 0                                   Unnamed: 1  \
# 0          NaN  This sheet allows you to manage executions:
# 1          NaN                           1. List executions
# 2          NaN                             2. Get execution
# 3          NaN                         3. Upsert executions
# 4          NaN                                          NaN
# ..         ...                                          ...
# 65         NaN                                          NaN
# 66         NaN                                          NaN
# 67         NaN                                          NaN
# 68         NaN                                          NaN
# 69         NaN                                          NaN
#
#            Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0                 NaN        NaN        NaN        NaN        NaN        NaN
# 1                 NaN        NaN        NaN        NaN        NaN        NaN
# ...

# %%
pd.read_excel("LUSID Excel - Manage Orders.xlsx", sheet_name= "Orders")
# Out:
#     Unnamed: 0                               Unnamed: 1     Unnamed: 2  \
# 0          NaN  This sheet allows you to manage Orders:            NaN
# 1          NaN                            1. ListOrders            NaN
# 2          NaN                              2. Getorder            NaN
# 3          NaN                          3. UpsertOrders            NaN
# 4          NaN                                      NaN            NaN
# ..         ...                                      ...            ...
# 66         NaN                                      NaN            NaN
# 67         NaN                                      NaN            NaN
# 68         NaN                                      NaN           Code
# 69         NaN                                      NaN  MyOrderCode02
# 70         NaN                                      NaN  MyOrderCode01
#
#    Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# ...

# %%
df2 = pd.read_excel("LUSID Excel - Manage Orders.xlsx")
df2
# Out:
#     Unnamed: 0                                   Unnamed: 1  \
# 0          NaN  This sheet allows you to manage executions:
# 1          NaN                           1. List executions
# 2          NaN                             2. Get execution
# 3          NaN                         3. Upsert executions
# 4          NaN                                          NaN
# ..         ...                                          ...
# 65         NaN                                          NaN
# 66         NaN                                          NaN
# 67         NaN                                          NaN
# 68         NaN                                          NaN
# 69         NaN                                          NaN
#
#            Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0                 NaN        NaN        NaN        NaN        NaN        NaN
# 1                 NaN        NaN        NaN        NaN        NaN        NaN
# ...

# %%
# in case you want to know the sheet in the excel file
import pandas as pd

# %%
df2 = pd.ExcelFile("LUSID Excel - Manage Orders.xlsx")

# %%
df2.sheet_names
# Out:
# ['Executions', 'Orders', 'Allocations', 'Placements', 'Blocks']

# %%
# read all the sheets one by one

# %%
k= []
for i in df2.sheet_names:
    k = pd.read_excel("LUSID Excel - Manage Orders.xlsx", sheet_name=i)

# %%
k
# Out:
#     Unnamed: 0                               Unnamed: 1  \
# 0          NaN  This sheet allows you to manage Blocks:
# 1          NaN                            1. ListBlocks
# 2          NaN                              2. GetBlock
# 3          NaN                          3. UpsertBlocks
# 4          NaN                                      NaN
# 5          NaN                                      NaN
# 6          NaN                                      NaN
# 7          NaN                                      NaN
# 8          NaN                  1. Get a list of blocks
# 9          NaN                                      NaN
# 10         NaN                                    asAt:
# 11         NaN                                      NaN
# 12         NaN                                  filter:
# 13         NaN                                      NaN
# 14         NaN                            propertyKeys:
# 15         NaN                                      NaN
# ...

# %%
df3 = pd.read_csv("https://github.com/datasciencedojo/datasets/blob/master/titanic.csv")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-8-998cadcc3eb5> in <module>
# ----> 1 df3 = pd.read_csv("https://github.com/datasciencedojo/datasets/blob/master/titanic.csv")
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
# ...

# %%
df3 = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df3
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df3 = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv" )

# %% [markdown]
# # PANDAS DAY 2

# %%
pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")
# it will try to scrap  the data only in the tabular format
# it will only scrap the data only in the tabular format from the html webpage
# html dr or
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
# currently data set is not in a readable format
# We have to make the data in the readable format

# %%
df4= pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")

# %%
type(df4)
# Out:
# list

# %%
# how many elements are there in the list

# %%
len(df4)
# Out:
# 1

# %%
df4[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
type(df4[0])
# Out:
# pandas.core.frame.DataFrame

# %%
df5 = df4[0]

# %%
df5.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df5.head()
# Out:
#   Rk         Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1     Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2   Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3   Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
# 3  4    Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23   54
# 4  5  Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27  220
#
#    TRB  AST STL BLK  TOV   PF   PTS
# 0  301   68  27  22   60  147   398
# 1   28   16  16   7   14   24    94
# 2  523   66  38  86   99  222   537
# 3   77   15   4   9    9   30    60
# 4  247  129  41   7  116  167  1035
#
# [5 rows x 30 columns]

# %%
df5.head(3)
# Out:
#   Rk        Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1    Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2  Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3  Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
#
#    TRB AST STL BLK TOV   PF  PTS
# 0  301  68  27  22  60  147  398
# 1   28  16  16   7  14   24   94
# 2  523  66  38  86  99  222  537
#
# [3 rows x 30 columns]

# %%
df5.dtypes
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# Tm        object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# dtype: object

# %%
df5[['Age', 'DRB']]
# Out:
#     Age  DRB
# 0    24  222
# 1    20   19
# 2    21  324
# 3    28   54
# 4    29  220
# ..   ..  ...
# 670  26  284
# 671  26  170
# 672  26  114
# 673  22  265
# 674  25  319
#
# [675 rows x 2 columns]

# %%
df5.to_csv("NBA.csv")

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is B8C0-2582
#
#  Directory of C:\Users\shrav\Documents\iNuron\pandas
#
# 07-03-2022  22:24    <DIR>          .
# 07-03-2022  21:52    <DIR>          ..
# 07-03-2022  16:32    <DIR>          .ipynb_checkpoints
# 07-03-2022  22:24           388,199 iNuron.ipynb
# 04-03-2022  08:28           161,651 LUSID Excel - Business Agility - Making Simple Changes Quickly & Easily.xlsx
# 04-03-2022  08:28           161,410 LUSID Excel - Maintain a product in multiple currencies and share classes.xlsx
# 04-03-2022  08:28            24,675 LUSID Excel - Manage instruments with economic definitions.xlsx
# 04-03-2022  08:28            84,319 LUSID Excel - Manage Orders.xlsx
# 04-03-2022  08:28           137,753 LUSID Excel - Manage your investment strategies.xlsx
# 04-03-2022  08:28           184,013 LUSID Excel - Setting up your IBOR.xlsx
# 04-03-2022  08:28           136,632 LUSID Excel - Setting up your market data.xlsx
# ...

# %%
# how to remove the row indexes

# %%
df5.to_csv("NBA_noindex.csv" , index= False)

# %%
l=pd.read_html('https://www.espncricinfo.com/series/world-cup-league-2-2019-2021-22-1196667/united-arab-emirates-vs-oman-60th-match-1302616/full-scorecard')

# %%
type(l)
# Out:
# list

# %%
len(l)
# Out:
# 9

# %%
l[0]
# Out:
#                                               BATTING  \
# 0                                   Kashyap Prajapati
# 1                                                 NaN
# 2                                      Jatinder Singh
# 3                                                 NaN
# 4                                         Shoaib Khan
# 5                                                 NaN
# 6                                          Ayaan Khan
# 7                                                 NaN
# 8                                 Zeeshan Maqsood (c)
# 9                                                 NaN
# 10                                      Suraj Kumar †
# 11                                                NaN
# 12                                       Sandeep Goud
# 13                                                NaN
# 14                                    Mohammad Nadeem
# 15                                                NaN
# ...

# %%
for i in range(len(l)):
    l[i]
    print(l[i])
# Out:
#                                               BATTING  \
# 0                                   Kashyap Prajapati
# 1                                                 NaN
# 2                                      Jatinder Singh
# 3                                                 NaN
# 4                                         Shoaib Khan
# 5                                                 NaN
# 6                                          Ayaan Khan
# 7                                                 NaN
# 8                                 Zeeshan Maqsood (c)
# 9                                                 NaN
# 10                                      Suraj Kumar †
# 11                                                NaN
# 12                                       Sandeep Goud
# 13                                                NaN
# 14                                    Mohammad Nadeem
# 15                                                NaN
# ...

# %%
d ="""{
 
"name": "Adviteeya Shrav",
"email": "shrav@gmail.com",
"tech": ["ML", "DL","CV"]

}
"""

# %%
# convert data into a tabular format

# %%
import json

# %%
json.loads(d)
# Out:
# {'name': 'Adviteeya Shrav',
#  'email': 'shrav@gmail.com',
#  'tech': ['ML', 'DL', 'CV']}

# %%
type(d)
# Out:
# str

# %%
m= json.loads(d)

# %%
m
# Out:
# {'name': 'Adviteeya Shrav',
#  'email': 'shrav@gmail.com',
#  'tech': ['ML', 'DL', 'CV']}

# %%
type(m)
# Out:
# dict

# %%
pd.read_json(m)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-6d3395c85d55> in <module>
# ----> 1 pd.read_json(m)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     197                 else:
#     198                     kwargs[new_arg_name] = new_arg_value
# --> 199             return func(*args, **kwargs)
#     200
#     201         return cast(F, wrapper)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     297                 )
#     298                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299             return func(*args, **kwargs)
#     300
#     301         return wrapper
#
# ...

# %%
pd.DataFrame(m)
# Out:
#               name            email tech
# 0  Adviteeya Shrav  shrav@gmail.com   ML
# 1  Adviteeya Shrav  shrav@gmail.com   DL
# 2  Adviteeya Shrav  shrav@gmail.com   CV

# %%
############# list to DataFrame is possible###########
############

# %%
d = {"packetType":"D","data":{"checkEngineLightFlag":"F","batteryVoltageStableTime":0,"batteryVoltageStable":"0","batteryVoltageOff":"12.42","batteryCrankParamTN":"-0.08","batteryCrankParamVN":"0.00","batteryCrankParamTP":"-0.08","batteryCrankParamVP":"0.00","batteryCrankParamTT":"-0.00008","batteryCrankParamV0":"0.00","batteryVoltageMaxOn":"13.05","batteryVoltageMinOn":"12.97","batteryVoltageMaxOff":"12.46","batteryVoltageMinOff":"12.36","batteryVoltageOnAverage":"13.02","engineLoadMax":"84","engineLoadAverage":"39.98","rpmMax":"3487","rpmAverage":"1431.29","gpsSpeedAverage":"21.99","vssMax":"53.44","vssAverage":"23.06","tcuTemperatureMin":"82.40","tcuTemperatureMax":"109.40","tcuTemperatureAverage":"104.87","coolantMin":"158.00","coolantMax":"188.60","coolantAverage":"180.20","packetStartLocal":1508143346000,"tripStartLocal":1508143346000,"milIndicator":"F","monitorsNotReady":0,"imei":"60DF5417","gatewayTs":1515613306592,"diagnosticTroubleCodeData":[],"diagnosticPidData":[[64768,47,100],[64768,1,517376],[64800,1,262144],[64768,5,125]]},"header":{"iwrapVer":"1.9.20","sourceSystem":"CDP","configVer":"1.1","oemName":"HUM","unitType":0,"cpVer":"7.50.1.9","igpsVer":"1.3.7","messageType":"Notification","pomVer":"1.0","headerVer":"V6","timestamp":0,"deviceType":"InDrive","visorVer":"1.4.35","transactionId":"53098471-7787-4160-94b3-cd69dcc70416","deviceSerialNo":"60DF5417","subOrganization":"HUM","organization":"HUM","imei":"60DF5417","operation":"Notification"}}

# %%
type(d)
# Out:
# pandas.core.frame.DataFrame

# %%
d1 = d['data']

# %%
d1
# Out:
# {'checkEngineLightFlag': 'F',
#  'batteryVoltageStableTime': 0,
#  'batteryVoltageStable': '0',
#  'batteryVoltageOff': '12.42',
#  'batteryCrankParamTN': '-0.08',
#  'batteryCrankParamVN': '0.00',
#  'batteryCrankParamTP': '-0.08',
#  'batteryCrankParamVP': '0.00',
#  'batteryCrankParamTT': '-0.00008',
#  'batteryCrankParamV0': '0.00',
#  'batteryVoltageMaxOn': '13.05',
#  'batteryVoltageMinOn': '12.97',
#  'batteryVoltageMaxOff': '12.46',
#  'batteryVoltageMinOff': '12.36',
#  'batteryVoltageOnAverage': '13.02',
#  'engineLoadMax': '84',
#  'engineLoadAverage': '39.98',
#  'rpmMax': '3487',
#  'rpmAverage': '1431.29',
#  'gpsSpeedAverage': '21.99',
#  'vssMax': '53.44',
#  'vssAverage': '23.06',
#  'tcuTemperatureMin': '82.40',
#  'tcuTemperatureMax': '109.40',
#  'tcuTemperatureAverage': '104.87',
#  'coolantMin': '158.00',
#  'coolantMax': '188.60',
#  'coolantAverage': '180.20',
#  'packetStartLocal': 1508143346000,
#  'tripStartLocal': 1508143346000,
#  'milIndicator': 'F',
# ...

# %%
pd.DataFrame(d1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-17ddab1ee376> in <module>
# ----> 1 pd.DataFrame(d1)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     527
#     528         elif isinstance(data, dict):
# --> 529             mgr = init_dict(data, index, columns, dtype=dtype)
#     530         elif isinstance(data, ma.MaskedArray):
#     531             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     285             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     286         ]
# --> 287     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     288
#     289
#
# ...

# %%
del d1['diagnosticTroubleCodeData']

# %%
d1
# Out:
# {'checkEngineLightFlag': 'F',
#  'batteryVoltageStableTime': 0,
#  'batteryVoltageStable': '0',
#  'batteryVoltageOff': '12.42',
#  'batteryCrankParamTN': '-0.08',
#  'batteryCrankParamVN': '0.00',
#  'batteryCrankParamTP': '-0.08',
#  'batteryCrankParamVP': '0.00',
#  'batteryCrankParamTT': '-0.00008',
#  'batteryCrankParamV0': '0.00',
#  'batteryVoltageMaxOn': '13.05',
#  'batteryVoltageMinOn': '12.97',
#  'batteryVoltageMaxOff': '12.46',
#  'batteryVoltageMinOff': '12.36',
#  'batteryVoltageOnAverage': '13.02',
#  'engineLoadMax': '84',
#  'engineLoadAverage': '39.98',
#  'rpmMax': '3487',
#  'rpmAverage': '1431.29',
#  'gpsSpeedAverage': '21.99',
#  'vssMax': '53.44',
#  'vssAverage': '23.06',
#  'tcuTemperatureMin': '82.40',
#  'tcuTemperatureMax': '109.40',
#  'tcuTemperatureAverage': '104.87',
#  'coolantMin': '158.00',
#  'coolantMax': '188.60',
#  'coolantAverage': '180.20',
#  'packetStartLocal': 1508143346000,
#  'tripStartLocal': 1508143346000,
#  'milIndicator': 'F',
# ...

# %%
pd.DataFrame(d1)
# Out:
#   checkEngineLightFlag  batteryVoltageStableTime batteryVoltageStable  \
# 0                    F                         0                    0
# 1                    F                         0                    0
# 2                    F                         0                    0
# 3                    F                         0                    0
#
#   batteryVoltageOff batteryCrankParamTN batteryCrankParamVN  \
# 0             12.42               -0.08                0.00
# 1             12.42               -0.08                0.00
# 2             12.42               -0.08                0.00
# 3             12.42               -0.08                0.00
#
#   batteryCrankParamTP batteryCrankParamVP batteryCrankParamTT  \
# 0               -0.08                0.00            -0.00008
# 1               -0.08                0.00            -0.00008
# 2               -0.08                0.00            -0.00008
# ...

# %%
############url = "https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
pd.read_json("https://api.github.com/repos/pandas-dev/pandas/issues")
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
# how to load the data into a raw json
# request a raw data from the url

# %%
import requests
url = "https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
data = requests.get(url)

# %%
data
# Out:
# <Response [200]>

# %%
data
# Out:
# <Response [200]>

# %%
data1 = data.json()
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46252',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46252/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46252/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46252/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46252',
#   'id': 1161597938,
#   'node_id': 'I_kwDOAA0YD85FPJPy',
#   'number': 46252,
#   'title': 'BUG: Period formatting directive %l (millisecond) and %u (microseconds) provide wrong results',
#   'user': {'login': 'smarie',
#    'id': 3236794,
#    'node_id': 'MDQ6VXNlcjMyMzY3OTQ=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3236794?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/smarie',
#    'html_url': 'https://github.com/smarie',
# ...

# %%
# how many unique dictionaries available

# %%
len(data1)
# Out:
# 30

# %%
############ give me userid from one dictionary

# %%
data1[0]['user']
# Out:
# {'login': 'smarie',
#  'id': 3236794,
#  'node_id': 'MDQ6VXNlcjMyMzY3OTQ=',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/3236794?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/smarie',
#  'html_url': 'https://github.com/smarie',
#  'followers_url': 'https://api.github.com/users/smarie/followers',
#  'following_url': 'https://api.github.com/users/smarie/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/smarie/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/smarie/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/smarie/subscriptions',
#  'organizations_url': 'https://api.github.com/users/smarie/orgs',
#  'repos_url': 'https://api.github.com/users/smarie/repos',
#  'events_url': 'https://api.github.com/users/smarie/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/smarie/received_events',
#  'type': 'User',
#  'site_admin': False}

# %%
data1[0]['user']['id']
# Out:
# 3236794

# %%
for i in range(len(data1)):
    print(data1[i]['user']['id'])
# Out:
# 3236794
# 97615200
# 25685004
# 3385756
# 20880292
# 8078968
# 1461273
# 36619387
# 56136443
# 20362314
# 30196
# 54762742
# 1020496
# 26364415
# 13765633
# 6618166
# 10712109
# 25179211
# 18547401
# 45562402
# 10820686
# 414652
# 10820686
# 46936498
# 51996504
# 25440862
# 5902745
# 4156237
# 100502242
# 10297014

# %%
pd.DataFrame(data1)
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
pd.DataFrame(data1 , columns= ['id','url','repository_url','labels_url','comments_url'])
# Out:
#             id                                                url  \
# 0   1161597938  https://api.github.com/repos/pandas-dev/pandas...
# 1   1161253063  https://api.github.com/repos/pandas-dev/pandas...
# 2   1161193811  https://api.github.com/repos/pandas-dev/pandas...
# 3   1161008604  https://api.github.com/repos/pandas-dev/pandas...
# 4   1160722098  https://api.github.com/repos/pandas-dev/pandas...
# 5   1160677456  https://api.github.com/repos/pandas-dev/pandas...
# 6   1160431471  https://api.github.com/repos/pandas-dev/pandas...
# 7   1160389512  https://api.github.com/repos/pandas-dev/pandas...
# 8   1160064471  https://api.github.com/repos/pandas-dev/pandas...
# 9   1159934807  https://api.github.com/repos/pandas-dev/pandas...
# 10  1159874789  https://api.github.com/repos/pandas-dev/pandas...
# 11  1159791857  https://api.github.com/repos/pandas-dev/pandas...
# 12  1159657724  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
pd.DataFrame(data1 , columns= ['id','url','repository_url','labels_url','comments_url','user'])
# Out:
#             id                                                url  \
# 0   1161597938  https://api.github.com/repos/pandas-dev/pandas...
# 1   1161253063  https://api.github.com/repos/pandas-dev/pandas...
# 2   1161193811  https://api.github.com/repos/pandas-dev/pandas...
# 3   1161008604  https://api.github.com/repos/pandas-dev/pandas...
# 4   1160722098  https://api.github.com/repos/pandas-dev/pandas...
# 5   1160677456  https://api.github.com/repos/pandas-dev/pandas...
# 6   1160431471  https://api.github.com/repos/pandas-dev/pandas...
# 7   1160389512  https://api.github.com/repos/pandas-dev/pandas...
# 8   1160064471  https://api.github.com/repos/pandas-dev/pandas...
# 9   1159934807  https://api.github.com/repos/pandas-dev/pandas...
# 10  1159874789  https://api.github.com/repos/pandas-dev/pandas...
# 11  1159791857  https://api.github.com/repos/pandas-dev/pandas...
# 12  1159657724  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
k= pd.DataFrame(data1 , columns= ['id','url','repository_url','labels_url','comments_url','user'])

# %%
k.to_csv('request.csv')

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is B8C0-2582
#
#  Directory of C:\Users\shrav\Documents\iNuron\pandas
#
# 08-03-2022  00:30    <DIR>          .
# 07-03-2022  21:52    <DIR>          ..
# 07-03-2022  16:32    <DIR>          .ipynb_checkpoints
# 08-03-2022  00:30           904,932 iNuron.ipynb
# 04-03-2022  08:28           161,651 LUSID Excel - Business Agility - Making Simple Changes Quickly & Easily.xlsx
# 04-03-2022  08:28           161,410 LUSID Excel - Maintain a product in multiple currencies and share classes.xlsx
# 04-03-2022  08:28            24,675 LUSID Excel - Manage instruments with economic definitions.xlsx
# 04-03-2022  08:28            84,319 LUSID Excel - Manage Orders.xlsx
# 04-03-2022  08:28           137,753 LUSID Excel - Manage your investment strategies.xlsx
# 04-03-2022  08:28           184,013 LUSID Excel - Setting up your IBOR.xlsx
# 04-03-2022  08:28           136,632 LUSID Excel - Setting up your market data.xlsx
# ...

# %%
u = pd.DataFrame(data1 , columns=['user'])

# %%
"""
{
'login': 'jbrockmendel',
'id': 8078968, 
'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4', 
'gravatar_id': '',
'url': 'https://api.github.com/users/jbrockmendel', 
'html_url': 'https://github.com/jbrockmendel',
'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}', 
'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}', 
'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs', 
'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
'type': 'User', 'site_admin': False}
"""

# %%
k=pd.DataFrame(u, columns=['user'])

# %%
len(u)
# Out:
# 30

# %%
type(u)
# Out:
# pandas.core.frame.DataFrame

# %%
type(k)
# Out:
# pandas.core.frame.DataFrame

# %%
k
# Out:
#                                                  user
# 0   {'login': 'smarie', 'id': 3236794, 'node_id': ...
# 1   {'login': 'haritha1022', 'id': 97615200, 'node...
# 2   {'login': 'franklucky001', 'id': 25685004, 'no...
# 3   {'login': 'eltenedor', 'id': 3385756, 'node_id...
# 4   {'login': 'ryansdowning', 'id': 20880292, 'nod...
# 5   {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 6   {'login': 'sterlinm', 'id': 1461273, 'node_id'...
# 7   {'login': 'weikhor', 'id': 36619387, 'node_id'...
# 8   {'login': 'LSturtew', 'id': 56136443, 'node_id...
# 9   {'login': 'ehallam', 'id': 20362314, 'node_id'...
# 10  {'login': 'ianliu', 'id': 30196, 'node_id': 'M...
# 11  {'login': 'raffaem', 'id': 54762742, 'node_id'...
# 12  {'login': 'jorisvandenbossche', 'id': 1020496,...
# 13  {'login': 'topper-123', 'id': 26364415, 'node_...
# 14  {'login': 'hitvoice', 'id': 13765633, 'node_id...
# 15  {'login': 'twoertwein', 'id': 6618166, 'node_i...
# ...

# %%
k['user']
# Out:
# 0     {'login': 'smarie', 'id': 3236794, 'node_id': ...
# 1     {'login': 'haritha1022', 'id': 97615200, 'node...
# 2     {'login': 'franklucky001', 'id': 25685004, 'no...
# 3     {'login': 'eltenedor', 'id': 3385756, 'node_id...
# 4     {'login': 'ryansdowning', 'id': 20880292, 'nod...
# 5     {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 6     {'login': 'sterlinm', 'id': 1461273, 'node_id'...
# 7     {'login': 'weikhor', 'id': 36619387, 'node_id'...
# 8     {'login': 'LSturtew', 'id': 56136443, 'node_id...
# 9     {'login': 'ehallam', 'id': 20362314, 'node_id'...
# 10    {'login': 'ianliu', 'id': 30196, 'node_id': 'M...
# 11    {'login': 'raffaem', 'id': 54762742, 'node_id'...
# 12    {'login': 'jorisvandenbossche', 'id': 1020496,...
# 13    {'login': 'topper-123', 'id': 26364415, 'node_...
# 14    {'login': 'hitvoice', 'id': 13765633, 'node_id...
# 15    {'login': 'twoertwein', 'id': 6618166, 'node_i...
# 16    {'login': 'mvashishtha', 'id': 10712109, 'node...
# ...

# %%
len(k)
# Out:
# 30

# %%
n=k['user'][0]

# %%
n
# Out:
# {'login': 'smarie',
#  'id': 3236794,
#  'node_id': 'MDQ6VXNlcjMyMzY3OTQ=',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/3236794?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/smarie',
#  'html_url': 'https://github.com/smarie',
#  'followers_url': 'https://api.github.com/users/smarie/followers',
#  'following_url': 'https://api.github.com/users/smarie/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/smarie/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/smarie/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/smarie/subscriptions',
#  'organizations_url': 'https://api.github.com/users/smarie/orgs',
#  'repos_url': 'https://api.github.com/users/smarie/repos',
#  'events_url': 'https://api.github.com/users/smarie/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/smarie/received_events',
#  'type': 'User',
#  'site_admin': False}

# %%
len(n)
# Out:
# 18

# %%
type(n)
# Out:
# dict

# %%
o = pd.DataFrame(n ,  index= [0])
o
# Out:
#     login       id               node_id  \
# 0  smarie  3236794  MDQ6VXNlcjMyMzY3OTQ=
#
#                                           avatar_url gravatar_id  \
# 0  https://avatars.githubusercontent.com/u/323679...
#
#                                    url                   html_url  \
# 0  https://api.github.com/users/smarie  https://github.com/smarie
#
#                                    followers_url  \
# 0  https://api.github.com/users/smarie/followers
#
#                                        following_url  \
# 0  https://api.github.com/users/smarie/following{...
#
#                                            gists_url  \
# 0  https://api.github.com/users/smarie/gists{/gis...
#
#                                          starred_url  \
# 0  https://api.github.com/users/smarie/starred{/o...
#
#                                    subscriptions_url  \
# 0  https://api.github.com/users/smarie/subscriptions
#
#                           organizations_url  \
# ...

# %%
for i in range(len(k)):
    n=k['user'][i]
    #print(n)
    for j in range(len(n)):
        o = pd.DataFrame(n,index= [j])
        print(o)
# Out:
#     login       id               node_id  \
# 0  smarie  3236794  MDQ6VXNlcjMyMzY3OTQ=
#
#                                           avatar_url gravatar_id  \
# 0  https://avatars.githubusercontent.com/u/323679...
#
#                                    url                   html_url  \
# 0  https://api.github.com/users/smarie  https://github.com/smarie
#
#                                    followers_url  \
# 0  https://api.github.com/users/smarie/followers
#
#                                        following_url  \
# 0  https://api.github.com/users/smarie/following{...
#
#                                            gists_url  \
# 0  https://api.github.com/users/smarie/gists{/gis...
#
#                                          starred_url  \
# 0  https://api.github.com/users/smarie/starred{/o...
#
#                                    subscriptions_url  \
# 0  https://api.github.com/users/smarie/subscriptions
#
#                           organizations_url  \
# ...

# %%
type(o)
# Out:
# pandas.core.frame.DataFrame

# %%
o.to_csv('usertest')

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is B8C0-2582
#
#  Directory of C:\Users\shrav\Documents\iNuron\pandas
#
# 08-03-2022  01:37    <DIR>          .
# 07-03-2022  21:52    <DIR>          ..
# 07-03-2022  16:32    <DIR>          .ipynb_checkpoints
# 08-03-2022  01:36         1,908,295 iNuron.ipynb
# 04-03-2022  08:28           161,651 LUSID Excel - Business Agility - Making Simple Changes Quickly & Easily.xlsx
# 04-03-2022  08:28           161,410 LUSID Excel - Maintain a product in multiple currencies and share classes.xlsx
# 04-03-2022  08:28            24,675 LUSID Excel - Manage instruments with economic definitions.xlsx
# 04-03-2022  08:28            84,319 LUSID Excel - Manage Orders.xlsx
# 04-03-2022  08:28           137,753 LUSID Excel - Manage your investment strategies.xlsx
# 04-03-2022  08:28           184,013 LUSID Excel - Setting up your IBOR.xlsx
# 04-03-2022  08:28           136,632 LUSID Excel - Setting up your market data.xlsx
# ...

# %% [markdown]
# #    # PANDAS DAY 3 DATA MANIPULATION

# %%
import pandas as pd

# %%
pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df10 = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
type(df10)
# Out:
# pandas.core.frame.DataFrame

# %%
df10.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df10.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df10.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df10.describe() # considered a columns having datatypes numeric non categorical data
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df10.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# How to find the description of the categorical data

# %%
df10.dtypes == 'object' # filter out all the columns with categorical data or object data types
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
type(df10.dtypes)
# Out:
# pandas.core.series.Series

# %%
# in case of series we have indices

# %%
df10.dtypes[df10.dtypes == 'object']
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
# my are of interest find the list of column name

# %%
# list of the column

# %%
df10.dtypes[df10.dtypes == 'object'].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
col_name = df10.dtypes[df10.dtypes == 'object'].index

# %%
col_name
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
df10[col_name].describe()
# Out:
#                      Name   Sex    Ticket    Cabin Embarked
# count                 891   891       891      204      889
# unique                891     2       681      147        3
# top     Taussig, Mr. Emil  male  CA. 2343  B96 B98        S
# freq                    1   577         7        4      644

# %%
# Add a new column

# %%
df10['iNuron'] = 'Adviteeya'

# %%
df10
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df10['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df10['Name'][0:15] # first 15 names
# Out:
# 0                               Braund, Mr. Owen Harris
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                Heikkinen, Miss. Laina
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                              Allen, Mr. William Henry
# 5                                      Moran, Mr. James
# 6                               McCarthy, Mr. Timothy J
# 7                        Palsson, Master. Gosta Leonard
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                   Nasser, Mrs. Nicholas (Adele Achem)
# 10                      Sandstrom, Miss. Marguerite Rut
# 11                             Bonnell, Miss. Elizabeth
# 12                       Saundercock, Mr. William Henry
# 13                          Andersson, Mr. Anders Johan
# 14                 Vestrom, Miss. Hulda Amanda Adolfina
# Name: Name, dtype: object

# %%
df10['Name'][0:15:2]
# Out:
# 0                               Braund, Mr. Owen Harris
# 2                                Heikkinen, Miss. Laina
# 4                              Allen, Mr. William Henry
# 6                               McCarthy, Mr. Timothy J
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 10                      Sandstrom, Miss. Marguerite Rut
# 12                       Saundercock, Mr. William Henry
# 14                 Vestrom, Miss. Hulda Amanda Adolfina
# Name: Name, dtype: object

# %%
df10['Name'][: : -1]
# Out:
# 890                                  Dooley, Mr. Patrick
# 889                                Behr, Mr. Karl Howell
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 887                         Graham, Miss. Margaret Edith
# 886                                Montvila, Rev. Juozas
#                              ...
# 4                               Allen, Mr. William Henry
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 2                                 Heikkinen, Miss. Laina
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 0                                Braund, Mr. Owen Harris
# Name: Name, Length: 891, dtype: object

# %%
df10
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# On what indexes we have a null value

# %%
df10['Age'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
df10['Age'].isnull()== True
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
df10[df10['Age'].isnull()== True]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df10[df10['Age'].isnull()== True].index  # How to get the index with the null value
# Out:
# Int64Index([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,
#             ...
#             832, 837, 839, 846, 849, 859, 863, 868, 878, 888],
#            dtype='int64', length=177)

# %%
len(df10[df10['Age'].isnull()== True].index)
# Out:
# 177

# %%
# How to go for the row wise selection

# %%
k = df10[df10['Age'].isnull()== True].index

# %%
df10.iloc[k]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df10.loc[k]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df10[df10['Age'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
# Find the person name who has paid the highest fare

# %%
df10[df10['Fare']==df10["Fare"].max()]
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
df10[df10['Fare']==df10["Fare"].max()]['Name']
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
#Q1 How many male and female passenger was onboarded
#Q2 How many survived we have 
#Q3 How many casualty we have
#Q4 What is the name of a person who is the eldest one
#Q5 How many passenger do we have in first , second and third class
#Q6 How many person we have whose name starts with letter "s"
#Q7 Try to create a new column which is a summation of "Sibsp" and "Parch"
#Q8 How many person do we have below age 25
#Q9 How many person died whose age was less than 40
#Q10 From a cabin column separate test and numeric value.

# %%
df10.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked     iNuron
# 0      0         A/5 21171   7.2500   NaN        S  Adviteeya
# 1      0          PC 17599  71.2833   C85        C  Adviteeya
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Adviteeya
# 3      0            113803  53.1000  C123        S  Adviteeya
# ...

# %%
df10[df10['Sex'] == 'male']
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked     iNuron
# ...

# %%
df10[df10['Sex'] == 'female']
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df10[df10['Survived']== 1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df10[df10['Survived']== 1]['Survived'].count()
# Out:
# 342

# %%
df10[df10['Survived']== 0]['Survived'].count()
# Out:
# 549

# %%
#Q4 What is the name of a person who is the eldest one

# %%
df10[df10['Age']== df10['Age'].max()]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#       Sex   Age  SibSp  Parch Ticket  Fare Cabin Embarked     iNuron
# 630  male  80.0      0      0  27042  30.0   A23        S  Adviteeya

# %%
#Q5 How many passenger do we have in first , second and third class

# %%
df10[df10['Pclass'] == 1]['Pclass'].count()
# Out:
# 216

# %%
df10[df10['Pclass'] == 2]['Pclass'].count()
# Out:
# 184

# %%
df10[df10['Pclass'] == 3]['Pclass'].count()
# Out:
# 491

# %%
#Q6 How many person we have whose name starts with letter "s"

# %%
c= 0
for i in range(len(df10['Name'])):
    if(df10['Name'][i][0] == 'S'):
        print(df10['Name'][i])
        c= c+1
print("Count of names starting with S = ",c)
# Out:
# Sandstrom, Miss. Marguerite Rut
# Saundercock, Mr. William Henry
# Sloper, Mr. William Thompson
# Spencer, Mrs. William Augustus (Marie Eugenie)
# Samaan, Mr. Youssef
# Sirayanian, Mr. Orsen
# Skoog, Master. Harald
# Stewart, Mr. Albert A
# Staneff, Mr. Ivan
# Sheerlinck, Mr. Jan Baptist
# Slocovski, Mr. Selman Francis
# Shorney, Mr. Charles Joseph
# Salkjelsvik, Miss. Anna Kristine
# Sobey, Mr. Samuel James Hayden
# Smiljanic, Mr. Mile
# Sage, Master. Thomas Henry
# Skoog, Mrs. William (Anna Bernhardina Karlsson)
# Sivola, Mr. Antti Wilhelm
# Smith, Mr. James Clinch
# Sage, Miss. Constance Gladys
# Sage, Mr. Frederick
# Strom, Miss. Telma Matilda
# Sunderland, Mr. Victor Francis
# Sjostedt, Mr. Ernst Adolf
# Strom, Mrs. Wilhelm (Elna Matilda Persson)
# Stead, Mr. William Thomas
# Smith, Mr. Thomas
# Smith, Mr. Richard William
# Stankovic, Mr. Ivan
# Saalfeld, Mr. Adolphe
# Spedden, Mrs. Frederic Oakley (Margaretta Corning Stone)
# Slayter, Miss. Hilda Mary
# ...

# %%
#Q7 Try to create a new column which is a summation of "Sibsp" and "Parch"

# %%
df10['New_Column'] = df10['SibSp'] + df10['Parch']

# %%
df10
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Q9 How many person died whose age was less than 40
#Q10 From a cabin column separate test and numeric value.

# %%
age_40=df10[df10['Age']< 40]

# %%
age_40
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
age_40[age_40['Survived']==0]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 0              1         0       3               Braund, Mr. Owen Harris
# 4              5         0       3              Allen, Mr. William Henry
# 7              8         0       3        Palsson, Master. Gosta Leonard
# 12            13         0       3        Saundercock, Mr. William Henry
# 13            14         0       3           Andersson, Mr. Anders Johan
# ..           ...       ...     ...                                   ...
# 883          884         0       2         Banfield, Mr. Frederick James
# 884          885         0       3                Sutehall, Mr. Henry Jr
# 885          886         0       3  Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                 Montvila, Rev. Juozas
# 890          891         0       3                   Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket    Fare Cabin Embarked  \
# ...

# %%
#Q10 From a cabin column separate text and numeric value.

# %%
df10['Cabin']
# Out:
# 0       NaN
# 1       C85
# 2       NaN
# 3      C123
# 4       NaN
#        ...
# 886     NaN
# 887     B42
# 888     NaN
# 889    C148
# 890     NaN
# Name: Cabin, Length: 891, dtype: object

# %%
df10[df10['Cabin'].isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import pandas as pd

# %%
df10[df10['Cabin'].notnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
type(df10[df10['Cabin'].notnull()])
# Out:
# pandas.core.frame.DataFrame

# %%
(df10[df10['Cabin'].notnull()]['Cabin']== int).count()
# Out:
# 687

# %%
(df10[df10['Cabin'].notnull()]['Cabin']== str).count()
# Out:
# 687

# %%
(df10[df10['Cabin'].isnull()])['Cabin'].count()
# Out:
# 0

# %%
df10['Cabin']
# Out:
# 0        1.0
# 1        NaN
# 2        3.0
# 3        NaN
# 4        5.0
#        ...
# 886    887.0
# 887      NaN
# 888    889.0
# 889      NaN
# 890    891.0
# Name: Cabin, Length: 891, dtype: object

# %% [markdown]
# #  COMPLEX BANK DATA SET

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is B8C0-2582
#
#  Directory of C:\Users\shrav\Documents\iNuron\pandas
#
# 10-03-2022  13:06    <DIR>          .
# 10-03-2022  00:07    <DIR>          ..
# 09-03-2022  20:28    <DIR>          .ipynb_checkpoints
# 14-02-2012  14:38           461,474 bank.csv
# 14-02-2012  14:40         4,610,348 bank-full.csv
# 14-02-2012  15:10             3,864 bank-names.txt
# 10-03-2022  12:11         2,106,019 iNuron.ipynb
# 04-03-2022  08:28           161,651 LUSID Excel - Business Agility - Making Simple Changes Quickly & Easily.xlsx
# 04-03-2022  08:28           161,410 LUSID Excel - Maintain a product in multiple currencies and share classes.xlsx
# 04-03-2022  08:28            24,675 LUSID Excel - Manage instruments with economic definitions.xlsx
# 04-03-2022  08:28            84,319 LUSID Excel - Manage Orders.xlsx
# 04-03-2022  08:28           137,753 LUSID Excel - Manage your investment strategies.xlsx
# ...

# %%
pd.read_csv("bank.csv" )
# Out:
#      age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"
# 0     30;"unemployed";"married";"primary";"no";1787;...
# 1     33;"services";"married";"secondary";"no";4789;...
# 2     35;"management";"single";"tertiary";"no";1350;...
# 3     30;"management";"married";"tertiary";"no";1476...
# 4     59;"blue-collar";"married";"secondary";"no";0;...
# ...                                                 ...
# 4516  33;"services";"married";"secondary";"no";-333;...
# 4517  57;"self-employed";"married";"tertiary";"yes";...
# 4518  57;"technician";"married";"secondary";"no";295...
# 4519  28;"blue-collar";"married";"secondary";"no";11...
# 4520  44;"entrepreneur";"single";"tertiary";"no";113...
#
# [4521 rows x 1 columns]

# %%
pd.read_csv("bank.csv" , delimiter=';')
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
pd.read_csv("bank-full.csv" , delimiter=';')
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
"""1 . how many campaign available in this dataset . 
2 . how many users do we have with housing and personal loan . 
3. how many person do we have whose age is 60+ . 
4 . in which month we have trageted most of the customer . 
5 . which mode of call is giving you more result
6 . how many enterpeures do we have in this list  
7 . how many customers do we have with negative balance 
8. prepare a group of data based on education level . 
"""

# %%
df11 = pd.read_csv("bank.csv" , delimiter=';')

# %%
df11
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
#1 . how many campaign available in this dataset . 
c=0
for i in range(len(df11['campaign'])):
    c= c+df11['campaign'][i]
print(c)
# Out:
# 12630

# %%
#2 . how many users do we have with housing and personal loan .
housing=df11[df11['housing']=='yes']['housing'].count()
print("housing loan count :", housing)
personal=df11[df11['loan']=='yes']['loan'].count()
print("personal loan count :", personal)
# Out:
# housing loan count : 2559
# personal loan count : 691

# %%
# 3. how many person do we have whose age is 60+ .
age60=df11[df11['age']>60]['age'].count()
print("Users above age  60 in the dataset is ", age60)
# Out:
# Users above age  60 in the dataset is  127

# %%
# 4 . in which month we have targeted most of the customer . 
month=df11['month'].unique()
print(month)
len(month)
month[0]
# Out:
# ['oct' 'may' 'apr' 'jun' 'feb' 'aug' 'jan' 'jul' 'nov' 'sep' 'mar' 'dec']
# 'oct'

# %%
targeted_customer=df11[df11['y']== "yes"]
targeted_customer
# Out:
#       age            job   marital  education default  balance housing loan  \
# 13     20        student    single  secondary      no      502      no   no
# 30     68        retired  divorced  secondary      no     4189      no   no
# 33     32     management    single   tertiary      no     2536     yes   no
# 34     49     technician   married   tertiary      no     1235      no   no
# 36     78        retired  divorced    primary      no      229      no   no
# ...   ...            ...       ...        ...     ...      ...     ...  ...
# 4494   26     technician    single  secondary      no      668     yes   no
# 4503   60  self-employed   married    primary      no      362      no  yes
# 4504   42    blue-collar    single  secondary      no     1080     yes  yes
# 4505   32         admin.    single  secondary      no      620     yes   no
# 4511   46    blue-collar   married  secondary      no      668     yes   no
#
# ...

# %%
l=targeted_users['month']
l
l.iloc[0]
# Out:
# 'apr'

# %%
j=0
a=0
ju=0
au=0
s=0
o=0
d=0
n=0
ma=0
jn=0
f=0
m=0
l=targeted_users['month']
for i in range(len(l)):
    if(l.iloc[i]== "jan"):
        j=j+1
    if(l.iloc[i]== "feb"):
        f=f+1
    if(l.iloc[i]== "mar"):
        m=m+1
    if(l.iloc[i]== "apr"):
        a=a+1
    if(l.iloc[i]== "may"):
        ma=ma+1
    if(l.iloc[i]== "jun"):
        jn=jn+1
    if(l.iloc[i]== "jul"):
        ju=ju+1
    if(l.iloc[i]== "aug"):
        au=au+1
    if(l.iloc[i]== "sep"):
        s=s+1
    if(l.iloc[i]== "oct"):
        o=o+1
    if(l.iloc[i]== "nov"):
        n=n+1
    if(l.iloc[i]== "dec"):
        d=d+1
print("Count in JAN month is :",j)
print("Count in FEB month is :",f)
print("Count in MAR month is :",m)
print("Count in APR month is :",a)
print("Count in MAY month is :",ma)
print("Count in JUN month is :",jn)
print("Count in JUL month is :",ju)
print("Count in AUG month is :",au)
print("Count in SEP month is :",s)
print("Count in OCT month is :",o)
print("Count in NOV month is :",n)
print("Count in DEC month is :",d)
# Out:
# Count in JAN month is : 16
# Count in FEB month is : 38
# Count in MAR month is : 21
# Count in APR month is : 56
# Count in MAY month is : 93
# Count in JUN month is : 55
# Count in JUL month is : 61
# Count in AUG month is : 79
# Count in SEP month is : 17
# Count in OCT month is : 37
# Count in NOV month is : 39
# Count in DEC month is : 9

# %%
"""c=0
max=0
l=targeted_users['month']
for i in range(len(month)):
    for j in range(len(l)):
        if(month[i]==l.loc[j]):
            c=c+1
            pass
    if(c>max):
        max=c
        mon = l[i]
    else:
        max=max
print("Month that have targeted most of the customers is ", mon)
"""
# Out:
# 'c=0\nmax=0\nl=targeted_users[\'month\']\nfor i in range(len(month)):\n    for j in range(len(l)):\n        if(month[i]==l.loc[j]):\n            c=c+1\n            pass\n    if(c>max):\n        max=c\n        mon = l[i]\n    else:\n        max=max\nprint("Month that have targeted most of the customers is ", mon)\n'

# %%
#c=0
k=df11[df11['month']=="jan"]['y'] == "yes"
print(k)
l=len(k)

#for i in range(len(k)):
#    if(k== True):
#        c=c+1

print("User in JAN month is :", l)
# Out:
# 14      False
# 24      False
# 49       True
# 66      False
# 113     False
#         ...
# 4410    False
# 4434    False
# 4479    False
# 4482    False
# 4488    False
# Name: y, Length: 148, dtype: bool
# User in JAN month is : 148

# %%
df11
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
#5 . which mode of call is giving you more result

# %%
call=df11['contact'].unique()
call
# Out:
# array(['cellular', 'unknown', 'telephone'], dtype=object)

# %%
df11['contact'][df11['contact']== "cellular"].count()
# Out:
# 2896

# %%
df11['contact'][df11['contact']== "unknown"].count()
# Out:
# 1324

# %%
df11['contact'][df11['contact']== "telephone"].count()
# Out:
# 301

# %%
"""6 . how many enterpeures do we have in this list

# %%
df11['job'][df11['job']== "entrepreneur"].count()
# Out:
# 168

# %%
"""7 . how many customers do we have with negative balance

# %%
df11['balance'][df11['balance']<0].count()
# Out:
# 366

# %%
"""8. prepare a group of data based on education level .

# %%
edu=df11['education'].unique()
edu
# Out:
# array(['primary', 'secondary', 'tertiary', 'unknown'], dtype=object)

# %%
for i in range(len(edu)):
    c=df11['education'][df11['education']== edu[i]].count()
    print("Count of education of users in",edu[i],"=",c)
# Out:
# Count of education of users in primary = 678
# Count of education of users in secondary = 2306
# Count of education of users in tertiary = 1350
# Count of education of users in unknown = 187

# %%
for i in range(len(edu)):
    d=df11[df11['education']== edu[i]]
    e= d['education'][d['y']== "yes"].count()
    print("Count of education of users who subscribed in",edu[i],"=",e)
# Out:
# Count of education of users who subscribed in primary = 64
# Count of education of users who subscribed in secondary = 245
# Count of education of users who subscribed in tertiary = 193
# Count of education of users who subscribed in unknown = 19

# %%
df11
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...
